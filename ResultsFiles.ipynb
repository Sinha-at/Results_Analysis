# %%
# %matplotlib inline
from dataFile import dataFile

# %% [markdown]
# Remark: Your file must be formated like the example in the file exDoc/exMatrix.xlsx, make sure your matrix are in the correct order: Demographic Info, pre-search Questionnaire, post-Search Questionnaire, User Experience, Cognitive Load, Software Usabilitiy

# %%
MyFile=dataFile(r'C:\Users\Nina\Desktop\Travail\ShortSample2.xlsx')
# Out:
# loading file...
# calculating results...
# converting data...
# task complete

# %% [markdown]
# Adding an argument 'pdf' to the function will download a pdf version of the information

# %%
MyFile.dt('pdf')
# Out:
# <style type="text/css">
# #T_e8687_ .row0 {
#   background-color: gray;
#   color: white;
#   border: 3px black;
# }
# #T_e8687_ thead {
#   visibility: collapse;
# }
# </style>
# <table id="T_e8687_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Transformed Data
# Here you can find the transformed values per item and the scale values per participant.  The +3 represent the most positive and the -3 the most negative value. </th>
#       <th class="col_heading level0 col1" >Unnamed: 1</th>
#       <th class="col_heading level0 col2" >Unnamed: 2</th>
#       <th class="col_heading level0 col3" >Unnamed: 3</th>
#       <th class="col_heading level0 col4" >Unnamed: 4</th>
#       <th class="col_heading level0 col5" >Unnamed: 5</th>
#       <th class="col_heading level0 col6" >Unnamed: 6</th>
#       <th class="col_heading level0 col7" >Unnamed: 7</th>
#       <th class="col_heading level0 col8" >Unnamed: 8</th>
# ...

# %%
MyFile.confidence_Intervals('pdf')
# Out:
# <style type="text/css">
# #T_ccee0_ .row0 {
#   background-color: gray;
#   color: white;
#   border: 3px black;
# }
# #T_ccee0_ .row1 {
#   background-color: gray;
#   color: white;
#   border: 3px black;
# }
# #T_ccee0_ .row2 {
#   background-color: gray;
#   color: white;
#   border: 3px black;
# }
# #T_ccee0_ thead {
#   visibility: collapse;
# }
# </style>
# <table id="T_ccee0_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Confidence intervals for items and scales
# ...

# %%
MyFile.scale_Consistency('pdf')
# Out:
# <style type="text/css">
# #T_c23f6_ .row0 {
#   background-color: gray;
#   color: white;
#   border: 3px black;
#   text-align: center;
# }
# #T_c23f6_ .row1 {
#   background-color: gray;
#   color: white;
#   border: 3px black;
# }
# #T_c23f6_ .row2 {
#   background-color: gray;
#   color: white;
#   border: 3px black;
# }
# #T_c23f6_ thead {
#   visibility: collapse;
# }
# </style>
# <table id="T_c23f6_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Correlations of the items per scale and Cronbachs Alpha-Coefficient
# ...

# %%
MyFile.benchmark('pdf')
# Out:
# <style type="text/css">
# #T_ace6d_ .row0 {
#   background-color: gray;
#   color: white;
#   border: 3px black;
# }
# #T_ace6d_ .row1 {
#   background-color: gray;
#   color: white;
#   border: 3px black;
# }
# #T_ace6d_ thead {
#   visibility: collapse;
# }
# </style>
# <table id="T_ace6d_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Benchmark
# ...

# %% [markdown]
# Adding an argument 'pdf' to the function will dowload the display in a pdf format

# %%
MyFile.results('pdf')
# Out:
# <style type="text/css">
# #T_c1817_ .row0 {
#   background-color: gray;
#   color: white;
#   border: 3px black;
# }
# #T_c1817_ .row1 {
#   background-color: gray;
#   color: white;
#   border: 3px black;
# }
# #T_c1817_ thead {
#   visibility: collapse;
# }
# </style>
# <table id="T_c1817_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Results
# You can interpret the means of the scales pragmatic quality and hedonic quality.
# Values between -0.8and 0.8 represent a neural evaluation of the corresponding scale,  values > 0,8 represent a positive evaluation and values < -0,8 represent a negative evaluation.
# ...

# %%
MyFile.inconsistencies('pdf')
# Out:
# <style type="text/css">
# #T_87db5_ .row0 {
#   background-color: gray;
#   color: white;
#   border: 3px black;
# }
# #T_87db5_ .row1 {
#   background-color: gray;
#   color: white;
#   border: 3px black;
# }
# #T_87db5_ thead {
#   visibility: collapse;
# }
# </style>
# <table id="T_87db5_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Detect Suspicious Data
# ...

# %%
MyFile.User_Experience_Qual_Analysis('pdf')
# Out:
# --------------------------------------------Qualitative User Experience Load--------------------------------------------
# loading pdf...
# pdf downloaded !

# %%
MyFile.cognitive_load()
# Out:
# --------------------------------------------Quantitative Cognitive Load--------------------------------------------

# %%
MyFile.cognitive_load_Qual_Analysis()
# Out:
# --------------------------------------------Qualitative Cognitive Load<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

# %%
MyFile.Software_Usability('pdf')
# Out:
# --------------------------------------------Quantitative Software Usability--------------------------------------------
# loading pdf...
# pdf downloaded !

# %%
MyFile.Software_Usability_Qual('pdf')
# Out:
# --------------------------------------------Qualitative Software Usability--------------------------------------------
# loading pdf...
# pdf downloaded !

# %%
MyFile.Software_Usability_Coments('pdf')
# Out:
# --------------------------------------------Software Usability coments--------------------------------------------
# <style type="text/css">
# #T_33aa6_ thead {
#   background-color: gray;
# }
# </style>
# <table id="T_33aa6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >System: If it was difficult to recover from any mistake, please comment on the problems.</th>
#       <th class="col_heading level0 col1" >Information:if any information was not clear, what difficulties did you face?</th>
#       <th class="col_heading level0 col2" >What functions and capabilities would you like to see in this system?</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33aa6_level0_row0" class="row_heading level0 row0" >Ur_1</th>
#       <td id="T_33aa6_row0_col0" class="data row0 col0" >The system itself suggest what you meant by understanding your questions.</td>
# ...

# %%
MyFile.Searching_Learning('pdf')
# Out:
# --------------------------------------------Quantitative Searching As Learning--------------------------------------------
# loading pdf...
# pdf downloaded !

# %%
MyFile.Searching_Learning_Qual('pdf')
# Out:
# --------------------------------------------Qualitative Searching As Learning--------------------------------------------
# loading pdf...
# pdf downloaded !

# %%
MyFile.Knowledge_Gain('pdf')
# Out:
# --------------------------------------------Quantitative Knowledge Gain--------------------------------------------
# loading pdf...
# pdf downloaded !

# %%
 MyFile.Knowledge_Gain_Qual_Analysis('pdf')
# Out:
# --------------------------------------------Qualitative Knowledge Gain--------------------------------------------
# loading pdf...
# pdf downloaded !
