# %%
# %matplotlib inline
from ComparedDataFile import ComparedDataFile

# %%
CompFile=ComparedDataFile(r'C:\Users\Nina\Desktop\Travail\ShortSample.xlsx',r'C:\Users\Nina\Desktop\Travail\ShortSample2.xlsx')
# Out:
# loading first file...
# calculating results...
# converting data...
# first file complete
# loading second file...
# calculating results...
# converting data...
# Second file complete

# %%
CompFile.confidence_Intervals('pdf')
# Out:
# file 1/file 2 confidence intervals
# <style type="text/css">
# #T_65c51_ thead {
#   visibility: collapse;
# }
# #T_65c51_ .row0 {
#   background-color: gray;
# }
# #T_65c51_ .row1 {
#   background-color: gray;
# }
# #T_65c51_ .row2 {
#   background-color: gray;
# }
# #T_65c51_ .row11 {
#   background-color: gray;
# }
# #T_65c51_ .row12 {
#   background-color: gray;
# }
# #T_65c51_ .row13 {
#   background-color: gray;
# }
# </style>
# <table id="T_65c51_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Confidence intervals for items and scales
# ...

# %%
CompFile.dt('pdf')
# Out:
# file 1/file 2 dt
# <style type="text/css">
# #T_dedf8_ thead {
#   visibility: collapse;
# }
# #T_dedf8_ .row0 {
#   background-color: gray;
# }
# #T_dedf8_ .row23 {
#   background-color: gray;
# }
# </style>
# <table id="T_dedf8_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Transformed Data
# Here you can find the transformed values per item and the scale values per participant.  The +3 represent the most positive and the -3 the most negative value. </th>
#       <th class="col_heading level0 col1" >Unnamed: 1</th>
#       <th class="col_heading level0 col2" >Unnamed: 2</th>
#       <th class="col_heading level0 col3" >Unnamed: 3</th>
#       <th class="col_heading level0 col4" >Unnamed: 4</th>
#       <th class="col_heading level0 col5" >Unnamed: 5</th>
#       <th class="col_heading level0 col6" >Unnamed: 6</th>
#       <th class="col_heading level0 col7" >Unnamed: 7</th>
#       <th class="col_heading level0 col8" >Unnamed: 8</th>
# ...

# %%
CompFile.scale_Consistency('pdf')
# Out:
# file 1/file 2 scale consistency
# <style type="text/css">
# #T_5121d_ thead {
#   visibility: collapse;
# }
# #T_5121d_ .row0 {
#   background-color: gray;
# }
# #T_5121d_ .row1 {
#   background-color: gray;
# }
# #T_5121d_ .row2 {
#   background-color: gray;
# }
# #T_5121d_ .row11 {
#   background-color: gray;
# }
# #T_5121d_ .row12 {
#   background-color: gray;
# }
# #T_5121d_ .row13 {
#   background-color: gray;
# }
# </style>
# <table id="T_5121d_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Correlations of the items per scale and Cronbachs Alpha-Coefficient
# ...

# %%
CompFile.benchmark('pdf')
# Out:
# file 1/file 2 benchmark
# <style type="text/css">
# #T_db271_ thead {
#   visibility: collapse;
# }
# #T_db271_ .row0 {
#   background-color: gray;
# }
# #T_db271_ .row33 {
#   background-color: gray;
# }
# </style>
# <table id="T_db271_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Benchmark
# ...

# %%
CompFile.results('pdf')
# Out:
# file 1/file 2 results
# <style type="text/css">
# #T_f8611_ thead {
#   visibility: collapse;
# }
# #T_f8611_ .row0 {
#   background-color: gray;
# }
# #T_f8611_ .row1 {
#   background-color: gray;
# }
# #T_f8611_ .row10 {
#   background-color: gray;
# }
# #T_f8611_ .row11 {
#   background-color: gray;
# }
# </style>
# <table id="T_f8611_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Results
# You can interpret the means of the scales pragmatic quality and hedonic quality.
# Values between -0.8and 0.8 represent a neural evaluation of the corresponding scale,  values > 0,8 represent a positive evaluation and values < -0,8 represent a negative evaluation.
# ...

# %%
CompFile.inconsistencies('pdf')
# Out:
# file 1/file 2 inconsistencies
# <style type="text/css">
# #T_7a127_ thead {
#   visibility: collapse;
# }
# #T_7a127_ .row0 {
#   background-color: gray;
# }
# #T_7a127_ .row23 {
#   background-color: gray;
# }
# </style>
# <table id="T_7a127_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Detect Suspicious Data
# ...

# %%
CompFile.cognitive_load('tab')
# Out:
# type of analysis: Quantitative
# type of test: t-test
# level of significance: 0.05
# Sample: independant
#                 categories    file 1    file 2   p-value significant diff  \
# 0       mentally demanding  2.666667  4.714286  0.000008              Yes
# 1      physicaly demanding  3.380952  4.904762  0.001244              Yes
# 2   hurried or rushed pace  3.380952  4.761905  0.001284              Yes
# 3               difficulty  3.428571  5.142857  0.000048              Yes
#
# 0                  success  2.714286  4.857143  0.000201              Yes
# 1  overall easiness to use  3.333333       5.0   0.00071              Yes
#
#   best file
# 0    file 1
# 1    file 1
# 2    file 1
# 3    file 1
#
# 0    file 2
# 1    file 2

# %%
CompFile.cognitive_load_Qual_Analysis()
# Out:
# type of analysis: Qualitative

# %%
CompFile.Knowledge_Gain('tab')
# Out:
# type of analysis: Quantitative
# type of test: t-test
# level of significance: 0.05
# Sample: independant
#        categories    file 1    file 2   p-value significant diff best file
# 0         quality  3.666667  5.095238  0.005714              Yes    file 2
# 1  interpretation  3.523810  4.523810  0.082581               No         /
# 2       critiques  4.142857  5.333333  0.010797              Yes    file 2

# %%
CompFile.Knowledge_Gain_Qual_Analysis()
# Out:
# type of analysis: Qualitative

# %%
CompFile.Software_Usability('tab')
# Out:
# type of analysis: Quantitative
# type of test: t-test
# level of significance: 0.05
# Sample: independant
#                                                   categories    file 1  \
# System
# 0                                          simplicity to use  3.333333
# 1                             helped effectivness of my work  3.047619
# 2                                     helped pace of my work  3.047619
# 3                                         confortable system  3.285714
# 4                                easy recovery after mistake  3.238095
# 5                                       overall satisfaction  3.571429
# Information
# 0                                                      clear   3.47619
# 1                                               easy to find  3.666667
# 2                                                  effective   3.47619
# 3                                                  organized   3.47619
# Interface
# ...

# %%
CompFile.Software_Usability_Qual()
# Out:
# type of analysis: Qualitative

# %%
CompFile.Searching_Learning('tab')
# Out:
# type of analysis: Quantitative
# type of test: t-test
# level of significance: 0.05
# Sample: independant
# 0.024818393452374205
#                                                        categories    file 1  \
# Search Formulation
# 0                                            background Knowledge  3.714286
# 1                                               interest in topic  3.809524
# 2                                          anticipated difficulty  3.666667
# Content Selection
# 0                                               actual difficulty  3.047619
# 1                                       text presentation quality  3.238095
# 2                           average number of doc view per search  3.333333
# 3                               the usefullness of search results  3.904762
# 4                                                  text relevance  3.952381
# Interaction with content
# 0                                             cognitively engaged  3.714286
# ...

# %%
CompFile.Searching_Learning_Qual()
# Out:
# type of analysis: Qualitative

# %%
CompFile.User_Experience_Qual_Analysis()
# Out:
# type of analysis: Qualitative

# %%
CompFile.Software_Usability_Coments()
# Out:
# <style type="text/css">
# #T_eb009_ thead {
#   background-color: gray;
# }
# #T_eb009_ .row21 {
#   background-color: gray;
# }
# </style>
# <table id="T_eb009_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >System: If it was difficult to recover from any mistake, please comment on the problems.</th>
#       <th class="col_heading level0 col1" >Information:if any information was not clear, what difficulties did you face?</th>
#       <th class="col_heading level0 col2" >What functions and capabilities would you like to see in this system?</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb009_level0_row0" class="row_heading level0 row0" >Ur_1</th>
#       <td id="T_eb009_row0_col0" class="data row0 col0" >The system itself suggest what you meant by understanding your questions.</td>
# ...

# %%
CompFile.info()
# Out:
#
# Quantitative analysis:
# benchmark (): Display information on the benchmark
# [ex: MyFile.benchmark()]
# Parameters:
# - save (String): ‘pdf’ to download the pdf version
#
# results (): Display information on the results of the analyse of the data
# [ex: MyFile. results ()]
# Parameters:
# - save (String): ‘pdf’ to download the pdf version
#
# dt (): Display information on the mid-calcul
# [ex: MyFile.dt()]
# Parameters:
# - save (String): ‘pdf’ to download the pdf version
#
#
# confidence_Intervals (): Display information on confidence intervals
# [ex: MyFile. confidence_Intervals ()]
# Parameters:
# - save (String): ‘pdf’ to download the pdf version
#
#
# scale_Consistency (): Display information on scale consistency
# [Ex : MyFile. Scale_Consistency ()]
# Parameters:
# - save (String): ‘pdf’ to download the pdf version
#
# Inconsistencies () : Display information on inconsistencies
# [Ex : MyFile. Inconsistencies ()]
# Parameters:
# ...
